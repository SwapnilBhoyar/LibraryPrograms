# %%
"""
@Author: Swapnil Bhoyar
@Date: 2021-07-14 
@Last Modified by: Swapnil Bhoyar
@Last Modified time: 2021-08-14
@Title : Matplotlib barchart programs.
"""

import Log
import matplotlib.pyplot as plt

language = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# %% [markdown]
# make border blue of each bar

# %%
plt.bar(language, popularity, edgecolor = "blue")
plt.xlabel("language")
plt.ylabel("popularity")
plt.show()

# %% [markdown]
# Horizontal bar chart

# %%
plt.barh(language, popularity)
plt.xlabel("popularity")
plt.ylabel("language")
plt.show()

# %% [markdown]
# use different colors

# %%
plt.bar(language, popularity, color = ['green', 'orange', 'black', 'red', 'blue', 'yellow'])
plt.xlabel("language")
plt.ylabel("popularity")
plt.show()

# %%
custoWidth = [0.1,0.2,0.5,1.1,0.2,0.3]
customPosition = [0,.8,1.5,3,5,6]
plt.bar(language, popularity, width = custoWidth)
plt.xticks(customPosition, language)
plt.xlabel("language")
plt.ylabel("popularity")
plt.show()

# %%
"""
@Author: Swapnil Bhoyar
@Date: 2021-07-13 
@Last Modified by: Swapnil Bhoyar
@Last Modified time: 2021-08-13
@Title : Write a Python program to iterate over rows in a DataFrame.
"""
import pandas as pd
import numpy as np
import Log

def iterateOverRow():
    try:
        exam_data  = {'name': ['Anastasia', 'Dima', 'Katherine', 'James', 'Emily', 'Michael', 'Matthew', 'Laura', 'Kevin', 'Jonas'],
            'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
            'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
            'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
        labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']

        tempDataframe = pd.DataFrame(exam_data , index=labels)
        for index, row in tempDataframe.iterrows():
            print(row['name'], row['qualify'])
    except Exception as e:
        Log.logging.info(e)

iterateOverRow()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Anastasia'
# Arguments: ('yes',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Dima'
# Arguments: ('no',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Katherine'
# Arguments: ('yes',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'James'
# Arguments: ('no',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Emily'
# Arguments: ('no',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Michael'
# Arguments: ('yes',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Matthew'
# Arguments: ('yes',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Laura'
# Arguments: ('no',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Kevin'
# Arguments: ('no',)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/usr/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/usr/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/usr/lib/python3.8/runpy.py", line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/usr/lib/python3.8/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/home/neo/.local/lib/python3.8/site-packages/traitlets/config/application.py", line 845, in launch_instance
#     app.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelapp.py", line 668, in start
#     self.io_loop.start()
#   File "/home/neo/.local/lib/python3.8/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 570, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.8/asyncio/base_events.py", line 1859, in _run_once
#     handle._run()
#   File "/usr/lib/python3.8/asyncio/events.py", line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 456, in dispatch_queue
#     await self.process_one()
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 445, in process_one
#     await dispatch(*args)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 352, in dispatch_shell
#     await result
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/kernelbase.py", line 647, in execute_request
#     reply_content = await reply_content
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/ipkernel.py", line 335, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/home/neo/.local/lib/python3.8/site-packages/ipykernel/zmqshell.py", line 532, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2898, in run_cell
#     result = self._run_cell(
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2944, in _run_cell
#     return runner(coro)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3169, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3361, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/home/neo/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3441, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_6479/1223053753.py", line 26, in <module>
#     iterateOverRow()
#   File "/tmp/ipykernel_6479/1223053753.py", line 22, in iterateOverRow
#     Log.logging.info(row['name'], row['qualify'])
# Message: 'Jonas'
# Arguments: ('yes',)
